# %%
import pickle
import cv2
import glob
import time
import numpy as np

from skimage.feature import hog
from sklearn.svm import LinearSVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from scipy.ndimage.measurements import label
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from moviepy.editor import VideoFileClip
from IPython.display import HTML
from sklearn.preprocessing import StandardScaler
from sklearn.cross_validation import train_test_split

# %matplotlib inline

# %%
# Load training data files
def load_training_set():
    trainning_vehicles = glob.glob('vehicles/*/*.png')
    training_non_vehicles = glob.glob('non-vehicles/*/*.png')
    print(len(trainning_vehicles), len(training_non_vehicles))
    return trainning_vehicles, training_non_vehicles

### TODO: Tweak these parameters and see how the results change.
color_space = 'RGB' # Can be RGB, HSV, LUV, HLS, YUV, YCrCb
orient = 9  # HOG orientations
pix_per_cell = 8 # HOG pixels per cell
cell_per_block = 2 # HOG cells per block
hog_channel = 0 # Can be 0, 1, 2, or "ALL"
spatial_size = (16, 16) # Spatial binning dimensions
hist_bins = 16    # Number of histogram bins
spatial_feat = True # Spatial features on or off
hist_feat = True # Histogram features on or off
hog_feat = True # HOG features on or off
y_start_stop = [None, None] # Min and max in y to search in slide_window()

# Define a function to return HOG features and visualization, copy from provided material
def get_hog_features(img, orient=orient, pix_per_cell=pix_per_cell, cell_per_block=cell_per_block, 
                        vis=False, feature_vec=True):
    # Call with two outputs if vis==True
    if vis == True:
        features, hog_image = hog(img, orientations=orient, 
                                  pixels_per_cell=(pix_per_cell, pix_per_cell),
                                  cells_per_block=(cell_per_block, cell_per_block), 
                                  transform_sqrt=True, 
                                  visualise=vis, feature_vector=feature_vec)
        return features, hog_image
    # Otherwise call with one output
    else:      
        features = hog(img, orientations=orient, 
                       pixels_per_cell=(pix_per_cell, pix_per_cell),
                       cells_per_block=(cell_per_block, cell_per_block), 
                       transform_sqrt=True, 
                       visualise=vis, feature_vector=feature_vec)
        return features

# %%
trainning_vehicles, training_non_vehicles = load_training_set()
v_image = mpimg.imread(trainning_vehicles[0])
n_v_image = mpimg.imread(training_non_vehicles[0])

vehicle_feature, vehicle_hog_image = get_hog_features(v_image[:,:,2], vis=True, feature_vec=True)
non_vehicle_feature, non_vehicle_hog_image = get_hog_features(n_v_image[:,:,2], vis=True, feature_vec=True)

#Plot vehicle and hog feature
fig = plt.figure()
plt.subplot(121)
plt.imshow(v_image, cmap='gray')
plt.subplot(122)
plt.imshow(vehicle_hog_image, cmap='gray')

#Plot non vehicle and hog feature
fig = plt.figure()
plt.subplot(121)
plt.imshow(n_v_image, cmap='gray')
plt.subplot(122)
plt.imshow(non_vehicle_hog_image, cmap='gray')
# Out:
# 8792 8968

# %%
# Define a function to compute binned color features  
def bin_spatial(img, size=(32, 32)):
    # Use cv2.resize().ravel() to create the feature vector
    features = cv2.resize(img, size).ravel() 
    # Return the feature vector
    return features

# Define a function to compute color histogram features  
def color_hist(img, nbins=32, bins_range=(0, 256)):
    # Compute the histogram of the color channels separately
    channel1_hist = np.histogram(img[:,:,0], bins=nbins, range=bins_range)
    channel2_hist = np.histogram(img[:,:,1], bins=nbins, range=bins_range)
    channel3_hist = np.histogram(img[:,:,2], bins=nbins, range=bins_range)
    # Concatenate the histograms into a single feature vector
    hist_features = np.concatenate((channel1_hist[0], channel2_hist[0], channel3_hist[0]))
    # Return the individual histograms, bin_centers and feature vector
    return hist_features

# Define a function to extract features from a list of images
# Have this function call bin_spatial() and color_hist()
def extract_features(imgs, color_space='RGB', spatial_size=(32, 32),
                        hist_bins=32, orient=9, 
                        pix_per_cell=8, cell_per_block=2, hog_channel=0,
                        spatial_feat=True, hist_feat=True, hog_feat=True):
    # Create a list to append feature vectors to
    features = []
    # Iterate through the list of images
    for file in imgs:
        print(file)
        file_features = []
        # Read in each one by one
        image = mpimg.imread(file)
        # apply color conversion if other than 'RGB'
        if color_space != 'RGB':
            if color_space == 'HSV':
                feature_image = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)
            elif color_space == 'LUV':
                feature_image = cv2.cvtColor(image, cv2.COLOR_RGB2LUV)
            elif color_space == 'HLS':
                feature_image = cv2.cvtColor(image, cv2.COLOR_RGB2HLS)
            elif color_space == 'YUV':
                feature_image = cv2.cvtColor(image, cv2.COLOR_RGB2YUV)
            elif color_space == 'YCrCb':
                feature_image = cv2.cvtColor(image, cv2.COLOR_RGB2YCrCb)
        else: feature_image = np.copy(image)      

        if spatial_feat == True:
            spatial_features = bin_spatial(feature_image, size=spatial_size)
            file_features.append(spatial_features)
        if hist_feat == True:
            # Apply color_hist()
            hist_features = color_hist(feature_image, nbins=hist_bins)
            file_features.append(hist_features)
        if hog_feat == True:
        # Call get_hog_features() with vis=False, feature_vec=True
            if hog_channel == 'ALL':
                hog_features = []
                for channel in range(feature_image.shape[2]):
                    hog_features.append(get_hog_features(feature_image[:,:,channel], 
                                        orient, pix_per_cell, cell_per_block, 
                                        vis=False, feature_vec=True))
                hog_features = np.ravel(hog_features)        
            else:
                hog_features = get_hog_features(feature_image[:,:,hog_channel], orient, 
                            pix_per_cell, cell_per_block, vis=False, feature_vec=True)
            # Append the new feature vector to the features list
            file_features.append(hog_features)
        features.append(np.concatenate(file_features))
    # Return list of feature vectors
    return features
print("start")
# build training vector set as well as labels
training_vehicles_features = extract_features(trainning_vehicles)
training_non_vehicles_features = extract_features(training_non_vehicles)
X_training = np.vstack((training_vehicles_features, training_non_vehicles_features)).astype(np.float64)
print(X_training.shape)
# Out:
# start
# vehicles\GTI_Far\image0000.png
# vehicles\GTI_Far\image0001.png
# vehicles\GTI_Far\image0002.png
# vehicles\GTI_Far\image0003.png
# vehicles\GTI_Far\image0004.png
# vehicles\GTI_Far\image0005.png
# vehicles\GTI_Far\image0006.png
# vehicles\GTI_Far\image0007.png
# vehicles\GTI_Far\image0008.png
# vehicles\GTI_Far\image0009.png
# vehicles\GTI_Far\image0010.png
# vehicles\GTI_Far\image0014.png
# vehicles\GTI_Far\image0015.png
# vehicles\GTI_Far\image0016.png
# vehicles\GTI_Far\image0018.png
# vehicles\GTI_Far\image0019.png
# vehicles\GTI_Far\image0021.png
# vehicles\GTI_Far\image0022.png
# vehicles\GTI_Far\image0023.png
# vehicles\GTI_Far\image0024.png
# vehicles\GTI_Far\image0027.png
# vehicles\GTI_Far\image0029.png
# vehicles\GTI_Far\image0030.png
# vehicles\GTI_Far\image0033.png
# vehicles\GTI_Far\image0036.png
# vehicles\GTI_Far\image0037.png
# vehicles\GTI_Far\image0039.png
# vehicles\GTI_Far\image0040.png
# vehicles\GTI_Far\image0041.png
# vehicles\GTI_Far\image0042.png
# vehicles\GTI_Far\image0043.png
# vehicles\GTI_Far\image0044.png
# vehicles\GTI_Far\image0045.png
# vehicles\GTI_Far\image0046.png
# vehicles\GTI_Far\image0047.png
# vehicles\GTI_Far\image0048.png
# vehicles\GTI_Far\image0049.png
# vehicles\GTI_Far\image0050.png
# vehicles\GTI_Far\image0051.png
# vehicles\GTI_Far\image0817.png
# vehicles\GTI_Far\image0818.png
# vehicles\GTI_Far\image0819.png
# vehicles\GTI_Far\image0822.png
# vehicles\GTI_Far\image0823.png
# vehicles\GTI_Far\image0824.png
# vehicles\GTI_Far\image0825.png
# vehicles\GTI_Far\image0826.png
# vehicles\GTI_Far\image0827.png
# vehicles\GTI_Far\image0828.png
# vehicles\GTI_Far\image0829.png
# vehicles\GTI_Far\image0832.png
# vehicles\GTI_Far\image0833.png
# vehicles\GTI_Far\image0834.png
# vehicles\GTI_Far\image0835.png
# vehicles\GTI_Far\image0836.png
# vehicles\GTI_Far\image0837.png
# vehicles\GTI_Far\image0838.png
# vehicles\GTI_Far\image0839.png
# vehicles\GTI_Far\image0840.png
# vehicles\GTI_Far\image0841.png
# vehicles\GTI_Far\image0842.png
# vehicles\GTI_Far\image0843.png
# vehicles\GTI_Far\image0844.png
# vehicles\GTI_Far\image0845.png
# vehicles\GTI_Far\image0846.png
# vehicles\GTI_Far\image0847.png
# vehicles\GTI_Far\image0848.png
# vehicles\GTI_Far\image0849.png
# vehicles\GTI_Far\image0850.png
# vehicles\GTI_Far\image0851.png
# vehicles\GTI_Far\image0852.png
# vehicles\GTI_Far\image0853.png
# vehicles\GTI_Far\image0854.png
# vehicles\GTI_Far\image0855.png
# vehicles\GTI_Far\image0856.png
# vehicles\GTI_Far\image0857.png
# vehicles\GTI_Far\image0858.png
# vehicles\GTI_Far\image0859.png
# vehicles\GTI_Far\image0860.png
# vehicles\GTI_Far\image0861.png
# vehicles\GTI_Far\image0862.png
# vehicles\GTI_Far\image0863.png
# vehicles\GTI_Far\image0864.png
# vehicles\GTI_Far\image0865.png
# vehicles\GTI_Far\image0866.png
# vehicles\GTI_Far\image0867.png
# vehicles\GTI_Far\image0868.png
# vehicles\GTI_Far\image0869.png
# vehicles\GTI_Far\image0870.png
# vehicles\GTI_Far\image0871.png
# vehicles\GTI_Far\image0872.png
# vehicles\GTI_Far\image0875.png
# vehicles\GTI_Far\image0876.png
# vehicles\GTI_Far\image0877.png
# vehicles\GTI_Far\image0878.png
# vehicles\GTI_Far\image0879.png
# vehicles\GTI_Far\image0880.png
# vehicles\GTI_Far\image0883.png
# vehicles\GTI_Far\image0884.png
# vehicles\GTI_Far\image0885.png
# vehicles\GTI_Far\image0886.png
# vehicles\GTI_Far\image0887.png
# vehicles\GTI_Far\image0888.png
# vehicles\GTI_Far\image0889.png
# vehicles\GTI_Far\image0890.png
# vehicles\GTI_Far\image0893.png
# vehicles\GTI_Far\image0894.png
# vehicles\GTI_Far\image0895.png
# vehicles\GTI_Far\image0896.png
# vehicles\GTI_Far\image0897.png
# vehicles\GTI_Far\image0898.png
# vehicles\GTI_Far\image0899.png
# vehicles\GTI_Far\image0900.png
# vehicles\GTI_Far\image0901.png
# vehicles\GTI_Far\image0902.png
# vehicles\GTI_Far\image0903.png
# vehicles\GTI_Far\image0904.png
# vehicles\GTI_Far\image0905.png
# vehicles\GTI_Far\image0906.png
# vehicles\GTI_Far\image0907.png
# vehicles\GTI_Far\image0908.png
# vehicles\GTI_Far\image0909.png
# vehicles\GTI_Far\image0910.png
# vehicles\GTI_Far\image0911.png
# vehicles\GTI_Far\image0914.png
# vehicles\GTI_Far\image0915.png
# vehicles\GTI_Far\image0916.png
# vehicles\GTI_Far\image0917.png
# vehicles\GTI_Far\image0918.png
# vehicles\GTI_Far\image0919.png
# vehicles\GTI_Far\image0920.png
# vehicles\GTI_Far\image0921.png
# vehicles\GTI_Far\image0922.png
# vehicles\GTI_Far\image0923.png
# vehicles\GTI_Far\image0924.png
# vehicles\GTI_Far\image0925.png
# vehicles\GTI_Far\image0926.png
# vehicles\GTI_Far\image0927.png
# vehicles\GTI_Far\image0928.png
# vehicles\GTI_Far\image0929.png
# vehicles\GTI_Far\image0930.png
# vehicles\GTI_Far\image0931.png
# vehicles\GTI_Far\image0932.png
# vehicles\GTI_Far\image0933.png
# vehicles\GTI_Far\image0934.png
# vehicles\GTI_Far\image0936.png
# vehicles\GTI_Far\image0937.png
# vehicles\GTI_Far\image0938.png
# vehicles\GTI_Far\image0939.png
# vehicles\GTI_Far\image0940.png
# vehicles\GTI_Far\image0941.png
# vehicles\GTI_Far\image0942.png
# vehicles\GTI_Far\image0943.png
# vehicles\GTI_Far\image0944.png
# vehicles\GTI_Far\image0945.png
# vehicles\GTI_Far\image0946.png
# vehicles\GTI_Far\image0947.png
# vehicles\GTI_Far\image0948.png
# vehicles\GTI_Far\image0949.png
# vehicles\GTI_Far\image0952.png
# vehicles\GTI_Far\image0953.png
# vehicles\GTI_Far\image0956.png
# vehicles\GTI_Far\image0957.png
# vehicles\GTI_Far\image0958.png
# vehicles\GTI_Far\image0959.png
# vehicles\GTI_Far\image0962.png
# vehicles\GTI_Far\image0963.png
# vehicles\GTI_Far\image0964.png
# vehicles\GTI_Far\image0965.png
# vehicles\GTI_Far\image0966.png
# vehicles\GTI_Far\image0967.png
# vehicles\GTI_Far\image0968.png
# vehicles\GTI_Far\image0971.png
# vehicles\GTI_Far\image0972.png
# vehicles\GTI_Far\image0973.png
# vehicles\GTI_Far\image0974.png
# vehicles\GTI_Left\image0009.png
# vehicles\GTI_Left\image0010.png
# vehicles\GTI_Left\image0011.png
# vehicles\GTI_Left\image0012.png
# vehicles\GTI_Left\image0013.png
# vehicles\GTI_Left\image0014.png
# vehicles\GTI_Left\image0015.png
# vehicles\GTI_Left\image0016.png
# vehicles\GTI_Left\image0017.png
# vehicles\GTI_Left\image0018.png
# vehicles\GTI_Left\image0019.png
# vehicles\GTI_Left\image0020.png
# vehicles\GTI_Left\image0021.png
# vehicles\GTI_Left\image0022.png
# vehicles\GTI_Left\image0023.png
# vehicles\GTI_Left\image0024.png
# vehicles\GTI_Left\image0025.png
# vehicles\GTI_Left\image0026.png
# vehicles\GTI_Left\image0027.png
# vehicles\GTI_Left\image0028.png
# vehicles\GTI_Left\image0029.png
# vehicles\GTI_Left\image0030.png
# vehicles\GTI_Left\image0031.png
# vehicles\GTI_Left\image0032.png
# vehicles\GTI_Left\image0033.png
# vehicles\GTI_Left\image0034.png
# vehicles\GTI_Left\image0035.png
# vehicles\GTI_Left\image0036.png
# vehicles\GTI_Left\image0037.png
# vehicles\GTI_Left\image0038.png
# vehicles\GTI_Left\image0039.png
# vehicles\GTI_Left\image0040.png
# vehicles\GTI_Left\image0041.png
# vehicles\GTI_Left\image0042.png
# vehicles\GTI_Left\image0043.png
# vehicles\GTI_Left\image0044.png
# vehicles\GTI_Left\image0045.png
# vehicles\GTI_Left\image0046.png
# vehicles\GTI_Left\image0047.png
# vehicles\GTI_Left\image0048.png
# vehicles\GTI_Left\image0049.png
# vehicles\GTI_Left\image0052.png
# vehicles\GTI_Left\image0053.png
# vehicles\GTI_Left\image0054.png
# vehicles\GTI_Left\image0057.png
# vehicles\GTI_Left\image0058.png
# vehicles\GTI_Left\image0059.png
# vehicles\GTI_Left\image0060.png
# vehicles\GTI_Left\image0061.png
# vehicles\GTI_Left\image0062.png
# vehicles\GTI_Left\image0063.png
# vehicles\GTI_Left\image0064.png
# vehicles\GTI_Left\image0065.png
# vehicles\GTI_Left\image0066.png
# vehicles\GTI_Left\image0067.png
# vehicles\GTI_Left\image0068.png
# vehicles\GTI_Left\image0069.png
# vehicles\GTI_Left\image0070.png
# vehicles\GTI_Left\image0071.png
# vehicles\GTI_Left\image0072.png
# vehicles\GTI_Left\image0073.png
# vehicles\GTI_Left\image0074.png
# vehicles\GTI_Left\image0075.png
# vehicles\GTI_Left\image0076.png
# vehicles\GTI_Left\image0077.png
# vehicles\GTI_Left\image0078.png
# vehicles\GTI_Left\image0079.png
# vehicles\GTI_Left\image0080.png
# vehicles\GTI_Left\image0081.png
# vehicles\GTI_Left\image0082.png
# vehicles\GTI_Left\image0083.png
# vehicles\GTI_Left\image0084.png
# vehicles\GTI_Left\image0085.png
# vehicles\GTI_Left\image0086.png
# vehicles\GTI_Left\image0087.png
# vehicles\GTI_Left\image0088.png
# vehicles\GTI_Left\image0089.png
# vehicles\GTI_Left\image0090.png
# vehicles\GTI_Left\image0091.png
# vehicles\GTI_Left\image0092.png
# vehicles\GTI_Left\image0093.png
# vehicles\GTI_Left\image0094.png
# vehicles\GTI_Left\image0095.png
# vehicles\GTI_Left\image0096.png
# vehicles\GTI_Left\image0097.png
# vehicles\GTI_Left\image0098.png
# vehicles\GTI_Left\image0116.png
# vehicles\GTI_Left\image0117.png
# vehicles\GTI_Left\image0118.png
# vehicles\GTI_Left\image0119.png
# vehicles\GTI_Left\image0120.png
# vehicles\GTI_Left\image0121.png
# vehicles\GTI_Left\image0122.png
# vehicles\GTI_Left\image0123.png
# vehicles\GTI_Left\image0124.png
# vehicles\GTI_Left\image0125.png
# vehicles\GTI_Left\image0126.png
# vehicles\GTI_Left\image0127.png
# vehicles\GTI_Left\image0128.png
# vehicles\GTI_Left\image0129.png
# vehicles\GTI_Left\image0130.png
# vehicles\GTI_Left\image0131.png
# vehicles\GTI_Left\image0132.png
# vehicles\GTI_Left\image0133.png
# vehicles\GTI_Left\image0134.png
# vehicles\GTI_Left\image0135.png
# vehicles\GTI_Left\image0136.png
# vehicles\GTI_Left\image0137.png
# vehicles\GTI_Left\image0138.png
# vehicles\GTI_Left\image0139.png
# vehicles\GTI_Left\image0140.png
# vehicles\GTI_Left\image0141.png
# vehicles\GTI_Left\image0142.png
# vehicles\GTI_Left\image0143.png
# vehicles\GTI_Left\image0144.png
# vehicles\GTI_Left\image0145.png
# vehicles\GTI_Left\image0146.png
# vehicles\GTI_Left\image0147.png
# vehicles\GTI_Left\image0148.png
# vehicles\GTI_Left\image0149.png
# vehicles\GTI_Left\image0150.png
# vehicles\GTI_Left\image0151.png
# vehicles\GTI_Left\image0152.png
# vehicles\GTI_Left\image0153.png
# vehicles\GTI_Left\image0154.png
# vehicles\GTI_Left\image0155.png
# vehicles\GTI_Left\image0156.png
# vehicles\GTI_Left\image0157.png
# vehicles\GTI_Left\image0158.png
# vehicles\GTI_Left\image0159.png
# vehicles\GTI_Left\image0160.png
# vehicles\GTI_Left\image0161.png
# vehicles\GTI_Left\image0162.png
# vehicles\GTI_Left\image0163.png
# vehicles\GTI_Left\image0164.png
# vehicles\GTI_Left\image0165.png
# vehicles\GTI_Left\image0166.png
# vehicles\GTI_Left\image0167.png
# vehicles\GTI_Left\image0168.png
# vehicles\GTI_Left\image0169.png
# vehicles\GTI_Left\image0170.png
# vehicles\GTI_Left\image0171.png
# vehicles\GTI_Left\image0172.png
# vehicles\GTI_Left\image0173.png
# vehicles\GTI_Left\image0174.png
# vehicles\GTI_Left\image0175.png
# vehicles\GTI_Left\image0176.png
# vehicles\GTI_Left\image0177.png
# vehicles\GTI_Left\image0178.png
# vehicles\GTI_Left\image0179.png
# vehicles\GTI_Left\image0180.png
# vehicles\GTI_Left\image0181.png
# vehicles\GTI_Left\image0182.png
# vehicles\GTI_Left\image0183.png
# vehicles\GTI_Left\image0184.png
# vehicles\GTI_Left\image0185.png
# vehicles\GTI_Left\image0186.png
# vehicles\GTI_Left\image0187.png
# vehicles\GTI_Left\image0188.png
# vehicles\GTI_Left\image0189.png
# vehicles\GTI_Left\image0190.png
# vehicles\GTI_Left\image0191.png
# vehicles\GTI_Left\image0192.png
# vehicles\GTI_Left\image0193.png
# vehicles\GTI_Left\image0194.png
# vehicles\GTI_Left\image0195.png
# vehicles\GTI_Left\image0196.png
# vehicles\GTI_Left\image0197.png
# vehicles\GTI_Left\image0198.png
# vehicles\GTI_Left\image0199.png
# vehicles\GTI_Left\image0208.png
# vehicles\GTI_Left\image0209.png
# vehicles\GTI_Left\image0210.png
# vehicles\GTI_Left\image0211.png
# vehicles\GTI_Left\image0212.png
# vehicles\GTI_Left\image0213.png
# vehicles\GTI_Left\image0214.png
# vehicles\GTI_Left\image0215.png
# vehicles\GTI_Left\image0216.png
# vehicles\GTI_Left\image0217.png
# vehicles\GTI_Left\image0218.png
# vehicles\GTI_Left\image0219.png
# vehicles\GTI_Left\image0220.png
# vehicles\GTI_Left\image0221.png
# vehicles\GTI_Left\image0222.png
# vehicles\GTI_Left\image0223.png
# vehicles\GTI_Left\image0224.png
# vehicles\GTI_Left\image0225.png
# vehicles\GTI_Left\image0226.png
# vehicles\GTI_Left\image0227.png
# vehicles\GTI_Left\image0228.png
# vehicles\GTI_Left\image0229.png
# vehicles\GTI_Left\image0230.png
# vehicles\GTI_Left\image0231.png
# vehicles\GTI_Left\image0232.png
# vehicles\GTI_Left\image0233.png
# vehicles\GTI_Left\image0234.png
# vehicles\GTI_Left\image0235.png
# vehicles\GTI_Left\image0236.png
# vehicles\GTI_Left\image0237.png
# vehicles\GTI_Left\image0238.png
# vehicles\GTI_Left\image0239.png
# vehicles\GTI_Left\image0240.png
# vehicles\GTI_Left\image0241.png
# vehicles\GTI_Left\image0242.png
# vehicles\GTI_Left\image0244.png
# vehicles\GTI_Left\image0245.png
# vehicles\GTI_Left\image0246.png
# vehicles\GTI_Left\image0247.png
# vehicles\GTI_Left\image0248.png
# vehicles\GTI_Left\image0249.png
# vehicles\GTI_Left\image0250.png
# vehicles\GTI_Left\image0251.png
# vehicles\GTI_Left\image0252.png
# vehicles\GTI_Left\image0253.png
# vehicles\GTI_Left\image0254.png
# vehicles\GTI_Left\image0255.png
# vehicles\GTI_Left\image0256.png
# vehicles\GTI_Left\image0257.png
# vehicles\GTI_Left\image0258.png
# vehicles\GTI_Left\image0259.png
# vehicles\GTI_Left\image0260.png
# vehicles\GTI_Left\image0261.png
# vehicles\GTI_Left\image0262.png
# vehicles\GTI_Left\image0263.png
# vehicles\GTI_Left\image0264.png
# vehicles\GTI_Left\image0265.png
# vehicles\GTI_Left\image0266.png
# vehicles\GTI_Left\image0267.png
# vehicles\GTI_Left\image0268.png
# vehicles\GTI_Left\image0269.png
# vehicles\GTI_Left\image0270.png
# vehicles\GTI_Left\image0271.png
# vehicles\GTI_Left\image0272.png
# vehicles\GTI_Left\image0273.png
# vehicles\GTI_Left\image0274.png
# vehicles\GTI_Left\image0275.png
# vehicles\GTI_Left\image0276.png
# vehicles\GTI_Left\image0277.png
# vehicles\GTI_Left\image0278.png
# vehicles\GTI_Left\image0279.png
# vehicles\GTI_Left\image0280.png
# vehicles\GTI_Left\image0281.png
# vehicles\GTI_Left\image0282.png
# vehicles\GTI_Left\image0283.png
# vehicles\GTI_Left\image0284.png
# vehicles\GTI_Left\image0285.png
# vehicles\GTI_Left\image0286.png
# vehicles\GTI_Left\image0287.png
# vehicles\GTI_Left\image0288.png
# vehicles\GTI_Left\image0289.png
# vehicles\GTI_Left\image0290.png
# vehicles\GTI_Left\image0291.png
# vehicles\GTI_Left\image0292.png
# vehicles\GTI_Left\image0293.png
# vehicles\GTI_Left\image0294.png
# vehicles\GTI_Left\image0295.png
# vehicles\GTI_Left\image0296.png
# vehicles\GTI_Left\image0297.png
# vehicles\GTI_Left\image0298.png
# vehicles\GTI_Left\image0299.png
# vehicles\GTI_Left\image0300.png
# vehicles\GTI_Left\image0301.png
# vehicles\GTI_Left\image0302.png
# vehicles\GTI_Left\image0303.png
# vehicles\GTI_Left\image0304.png
# vehicles\GTI_Left\image0305.png
# vehicles\GTI_Left\image0306.png
# vehicles\GTI_Left\image0307.png
# vehicles\GTI_Left\image0308.png
# vehicles\GTI_Left\image0309.png
# vehicles\GTI_Left\image0310.png
# vehicles\GTI_Left\image0311.png
# vehicles\GTI_Left\image0312.png
# vehicles\GTI_Left\image0313.png
# vehicles\GTI_Left\image0314.png
# vehicles\GTI_Left\image0315.png
# vehicles\GTI_Left\image0316.png
# vehicles\GTI_Left\image0317.png
# vehicles\GTI_Left\image0318.png
# vehicles\GTI_Left\image0319.png
# vehicles\GTI_Left\image0320.png
# vehicles\GTI_Left\image0321.png
# vehicles\GTI_Left\image0322.png
# vehicles\GTI_Left\image0323.png
# vehicles\GTI_Left\image0324.png
# vehicles\GTI_Left\image0325.png
# vehicles\GTI_Left\image0326.png
# vehicles\GTI_Left\image0327.png
# vehicles\GTI_Left\image0328.png
# vehicles\GTI_Left\image0329.png
# vehicles\GTI_Left\image0330.png
# vehicles\GTI_Left\image0331.png
# vehicles\GTI_Left\image0332.png
# vehicles\GTI_Left\image0333.png
# vehicles\GTI_Left\image0334.png
# vehicles\GTI_Left\image0335.png
# vehicles\GTI_Left\image0336.png
# vehicles\GTI_Left\image0337.png
# vehicles\GTI_Left\image0338.png
# vehicles\GTI_Left\image0339.png
# vehicles\GTI_Left\image0340.png
# vehicles\GTI_Left\image0341.png
# vehicles\GTI_Left\image0342.png
# vehicles\GTI_Left\image0343.png
# vehicles\GTI_Left\image0344.png
# vehicles\GTI_Left\image0345.png
# vehicles\GTI_Left\image0346.png
# vehicles\GTI_Left\image0347.png
# vehicles\GTI_Left\image0348.png
# vehicles\GTI_Left\image0349.png
# vehicles\GTI_Left\image0350.png
# vehicles\GTI_Left\image0351.png
# vehicles\GTI_Left\image0352.png
# vehicles\GTI_Left\image0353.png
# vehicles\GTI_Left\image0354.png
# vehicles\GTI_Left\image0355.png
# vehicles\GTI_Left\image0356.png
# vehicles\GTI_Left\image0357.png
# vehicles\GTI_Left\image0358.png
# vehicles\GTI_Left\image0359.png
# vehicles\GTI_Left\image0360.png
# vehicles\GTI_Left\image0361.png
# vehicles\GTI_Left\image0362.png
# vehicles\GTI_Left\image0363.png
# vehicles\GTI_Left\image0364.png
# vehicles\GTI_Left\image0365.png
# vehicles\GTI_Left\image0366.png
# vehicles\GTI_Left\image0367.png
# vehicles\GTI_Left\image0368.png
# vehicles\GTI_Left\image0369.png
# vehicles\GTI_Left\image0370.png
# vehicles\GTI_Left\image0371.png
# vehicles\GTI_Left\image0372.png
# vehicles\GTI_Left\image0373.png
# vehicles\GTI_Left\image0374.png
# vehicles\GTI_Left\image0375.png
# vehicles\GTI_Left\image0377.png
# vehicles\GTI_Left\image0378.png
# vehicles\GTI_Left\image0379.png
# vehicles\GTI_Left\image0380.png
# vehicles\GTI_Left\image0381.png
# vehicles\GTI_Left\image0382.png
# vehicles\GTI_Left\image0383.png
# vehicles\GTI_Left\image0384.png
# vehicles\GTI_Left\image0385.png
# vehicles\GTI_Left\image0386.png
# vehicles\GTI_Left\image0387.png
# vehicles\GTI_Left\image0388.png
# vehicles\GTI_Left\image0390.png
# vehicles\GTI_Left\image0391.png
# vehicles\GTI_Left\image0392.png
# vehicles\GTI_Left\image0393.png
# vehicles\GTI_Left\image0394.png
# vehicles\GTI_Left\image0395.png
# vehicles\GTI_Left\image0396.png
# vehicles\GTI_Left\image0397.png
# vehicles\GTI_Left\image0398.png
# vehicles\GTI_Left\image0399.png
# vehicles\GTI_Left\image0400.png
# vehicles\GTI_Left\image0401.png
# vehicles\GTI_Left\image0402.png
# vehicles\GTI_Left\image0403.png
# vehicles\GTI_Left\image0404.png
# vehicles\GTI_Left\image0405.png
# vehicles\GTI_Left\image0406.png
# vehicles\GTI_Left\image0407.png
# vehicles\GTI_Left\image0408.png
# vehicles\GTI_Left\image0409.png
# vehicles\GTI_Left\image0410.png
# vehicles\GTI_Left\image0411.png
# vehicles\GTI_Left\image0412.png
# vehicles\GTI_Left\image0413.png
# vehicles\GTI_Left\image0414.png
# vehicles\GTI_Left\image0415.png
# vehicles\GTI_Left\image0416.png
# vehicles\GTI_Left\image0417.png
# vehicles\GTI_Left\image0418.png
# vehicles\GTI_Left\image0419.png
# vehicles\GTI_Left\image0420.png
# vehicles\GTI_Left\image0421.png
# vehicles\GTI_Left\image0422.png
# vehicles\GTI_Left\image0423.png
# vehicles\GTI_Left\image0424.png
# vehicles\GTI_Left\image0425.png
# vehicles\GTI_Left\image0426.png
# vehicles\GTI_Left\image0427.png
# vehicles\GTI_Left\image0428.png
# vehicles\GTI_Left\image0429.png
# vehicles\GTI_Left\image0430.png
# vehicles\GTI_Left\image0431.png
# vehicles\GTI_Left\image0432.png
# vehicles\GTI_Left\image0433.png
# vehicles\GTI_Left\image0434.png
# vehicles\GTI_Left\image0435.png
# vehicles\GTI_Left\image0436.png
# vehicles\GTI_Left\image0437.png
# vehicles\GTI_Left\image0438.png
# vehicles\GTI_Left\image0439.png
# vehicles\GTI_Left\image0440.png
# vehicles\GTI_Left\image0441.png
# vehicles\GTI_Left\image0442.png
# vehicles\GTI_Left\image0443.png
# vehicles\GTI_Left\image0444.png
# vehicles\GTI_Left\image0445.png
# vehicles\GTI_Left\image0446.png
# vehicles\GTI_Left\image0447.png
# vehicles\GTI_Left\image0448.png
# vehicles\GTI_Left\image0449.png
# vehicles\GTI_Left\image0450.png
# vehicles\GTI_Left\image0451.png
# vehicles\GTI_Left\image0452.png
# vehicles\GTI_Left\image0453.png
# vehicles\GTI_Left\image0454.png
# vehicles\GTI_Left\image0455.png
# vehicles\GTI_Left\image0456.png
# vehicles\GTI_Left\image0457.png
# vehicles\GTI_Left\image0458.png
# vehicles\GTI_Left\image0459.png
# vehicles\GTI_Left\image0460.png
# vehicles\GTI_Left\image0461.png
# vehicles\GTI_Left\image0462.png
# vehicles\GTI_Left\image0463.png
# vehicles\GTI_Left\image0464.png
# vehicles\GTI_Left\image0465.png
# vehicles\GTI_Left\image0466.png
# vehicles\GTI_Left\image0467.png
# vehicles\GTI_Left\image0468.png
# vehicles\GTI_Left\image0469.png
# vehicles\GTI_Left\image0470.png
# vehicles\GTI_Left\image0471.png
# vehicles\GTI_Left\image0472.png
# vehicles\GTI_Left\image0473.png
# vehicles\GTI_Left\image0474.png
# vehicles\GTI_Left\image0475.png
# vehicles\GTI_Left\image0476.png
# vehicles\GTI_Left\image0477.png
# vehicles\GTI_Left\image0478.png
# vehicles\GTI_Left\image0479.png
# vehicles\GTI_Left\image0480.png
# vehicles\GTI_Left\image0481.png
# vehicles\GTI_Left\image0482.png
# vehicles\GTI_Left\image0483.png
# vehicles\GTI_Left\image0484.png
# vehicles\GTI_Left\image0485.png
# vehicles\GTI_Left\image0486.png
# vehicles\GTI_Left\image0487.png
# vehicles\GTI_Left\image0488.png
# vehicles\GTI_Left\image0489.png
# vehicles\GTI_Left\image0490.png
# vehicles\GTI_Left\image0491.png
# vehicles\GTI_Left\image0492.png
# vehicles\GTI_Left\image0493.png
# vehicles\GTI_Left\image0494.png
# vehicles\GTI_Left\image0495.png
# vehicles\GTI_Left\image0496.png
# vehicles\GTI_Left\image0497.png
# vehicles\GTI_Left\image0498.png
# vehicles\GTI_Left\image0499.png
# vehicles\GTI_Left\image0500.png
# vehicles\GTI_Left\image0501.png
# vehicles\GTI_Left\image0502.png
# vehicles\GTI_Left\image0503.png
# vehicles\GTI_Left\image0504.png
# vehicles\GTI_Left\image0505.png
# vehicles\GTI_Left\image0506.png
# vehicles\GTI_Left\image0507.png
# vehicles\GTI_Left\image0508.png
# vehicles\GTI_Left\image0509.png
# vehicles\GTI_Left\image0510.png
# vehicles\GTI_Left\image0511.png
# vehicles\GTI_Left\image0512.png
# vehicles\GTI_Left\image0513.png
# vehicles\GTI_Left\image0514.png
# vehicles\GTI_Left\image0515.png
# vehicles\GTI_Left\image0516.png
# vehicles\GTI_Left\image0517.png
# vehicles\GTI_Left\image0518.png
# vehicles\GTI_Left\image0519.png
# vehicles\GTI_Left\image0520.png
# vehicles\GTI_Left\image0521.png
# vehicles\GTI_Left\image0522.png
# vehicles\GTI_Left\image0523.png
# vehicles\GTI_Left\image0524.png
# vehicles\GTI_Left\image0525.png
# vehicles\GTI_Left\image0526.png
# vehicles\GTI_Left\image0527.png
# vehicles\GTI_Left\image0528.png
# vehicles\GTI_Left\image0529.png
# vehicles\GTI_Left\image0530.png
# vehicles\GTI_Left\image0531.png
# vehicles\GTI_Left\image0532.png
# vehicles\GTI_Left\image0533.png
# vehicles\GTI_Left\image0534.png
# vehicles\GTI_Left\image0535.png
# vehicles\GTI_Left\image0536.png
# vehicles\GTI_Left\image0537.png
# vehicles\GTI_Left\image0538.png
# vehicles\GTI_Left\image0539.png
# vehicles\GTI_Left\image0540.png
# vehicles\GTI_Left\image0541.png
# vehicles\GTI_Left\image0542.png
# vehicles\GTI_Left\image0543.png
# vehicles\GTI_Left\image0544.png
# vehicles\GTI_Left\image0545.png
# vehicles\GTI_Left\image0546.png
# vehicles\GTI_Left\image0547.png
# vehicles\GTI_Left\image0548.png
# vehicles\GTI_Left\image0549.png
# vehicles\GTI_Left\image0550.png
# vehicles\GTI_Left\image0551.png
# vehicles\GTI_Left\image0552.png
# vehicles\GTI_Left\image0554.png
# vehicles\GTI_Left\image0558.png
# vehicles\GTI_Left\image0559.png
# vehicles\GTI_Left\image0560.png
# vehicles\GTI_Left\image0561.png
# vehicles\GTI_Left\image0562.png
# vehicles\GTI_Left\image0563.png
# vehicles\GTI_Left\image0564.png
# vehicles\GTI_Left\image0565.png
# vehicles\GTI_Left\image0567.png
# vehicles\GTI_Left\image0568.png
# vehicles\GTI_Left\image0569.png
# vehicles\GTI_Left\image0570.png
# vehicles\GTI_Left\image0571.png
# vehicles\GTI_Left\image0572.png
# vehicles\GTI_Left\image0573.png
# vehicles\GTI_Left\image0574.png
# vehicles\GTI_Left\image0575.png
# vehicles\GTI_Left\image0576.png
# vehicles\GTI_Left\image0577.png
# vehicles\GTI_Left\image0578.png
# vehicles\GTI_Left\image0579.png
# vehicles\GTI_Left\image0580.png
# vehicles\GTI_Left\image0581.png
# vehicles\GTI_Left\image0582.png
# vehicles\GTI_Left\image0583.png
# vehicles\GTI_Left\image0584.png
# vehicles\GTI_Left\image0585.png
# vehicles\GTI_Left\image0586.png
# vehicles\GTI_Left\image0587.png
# vehicles\GTI_Left\image0588.png
# vehicles\GTI_Left\image0589.png
# vehicles\GTI_Left\image0590.png
# vehicles\GTI_Left\image0591.png
# vehicles\GTI_Left\image0592.png
# vehicles\GTI_Left\image0593.png
# vehicles\GTI_Left\image0594.png
# vehicles\GTI_Left\image0595.png
# vehicles\GTI_Left\image0596.png
# vehicles\GTI_Left\image0597.png
# vehicles\GTI_Left\image0598.png
# vehicles\GTI_Left\image0599.png
# vehicles\GTI_Left\image0601.png
# vehicles\GTI_Left\image0602.png
# vehicles\GTI_Left\image0603.png
# vehicles\GTI_Left\image0604.png
# vehicles\GTI_Left\image0605.png
# vehicles\GTI_Left\image0606.png
# vehicles\GTI_Left\image0607.png
# vehicles\GTI_Left\image0608.png
# vehicles\GTI_Left\image0609.png
# vehicles\GTI_Left\image0610.png
# vehicles\GTI_Left\image0611.png
# vehicles\GTI_Left\image0612.png
# vehicles\GTI_Left\image0613.png
# vehicles\GTI_Left\image0614.png
# vehicles\GTI_Left\image0615.png
# vehicles\GTI_Left\image0616.png
# vehicles\GTI_Left\image0617.png
# vehicles\GTI_Left\image0618.png
# vehicles\GTI_Left\image0619.png
# vehicles\GTI_Left\image0620.png
# vehicles\GTI_Left\image0621.png
# vehicles\GTI_Left\image0622.png
# vehicles\GTI_Left\image0623.png
# vehicles\GTI_Left\image0628.png
# vehicles\GTI_Left\image0629.png
# vehicles\GTI_Left\image0630.png
# vehicles\GTI_Left\image0631.png
# vehicles\GTI_Left\image0632.png
# vehicles\GTI_Left\image0633.png
# vehicles\GTI_Left\image0634.png
# vehicles\GTI_Left\image0635.png
# vehicles\GTI_Left\image0636.png
# vehicles\GTI_Left\image0637.png
# vehicles\GTI_Left\image0638.png
# vehicles\GTI_Left\image0639.png
# vehicles\GTI_Left\image0640.png
# vehicles\GTI_Left\image0641.png
# vehicles\GTI_Left\image0642.png
# vehicles\GTI_Left\image0643.png
# vehicles\GTI_Left\image0644.png
# vehicles\GTI_Left\image0645.png
# vehicles\GTI_Left\image0646.png
# vehicles\GTI_Left\image0647.png
# vehicles\GTI_Left\image0648.png
# vehicles\GTI_Left\image0649.png
# vehicles\GTI_Left\image0650.png
# vehicles\GTI_Left\image0651.png
# vehicles\GTI_Left\image0652.png
# vehicles\GTI_Left\image0653.png
# vehicles\GTI_Left\image0654.png
# vehicles\GTI_Left\image0655.png
# vehicles\GTI_Left\image0656.png
# vehicles\GTI_Left\image0657.png
# vehicles\GTI_Left\image0658.png
# vehicles\GTI_Left\image0659.png
# vehicles\GTI_Left\image0660.png
# vehicles\GTI_Left\image0661.png
# vehicles\GTI_Left\image0662.png
# vehicles\GTI_Left\image0663.png
# vehicles\GTI_Left\image0664.png
# vehicles\GTI_Left\image0665.png
# vehicles\GTI_Left\image0666.png
# vehicles\GTI_Left\image0667.png
# vehicles\GTI_Left\image0668.png
# vehicles\GTI_Left\image0669.png
# vehicles\GTI_Left\image0670.png
# vehicles\GTI_Left\image0671.png
# vehicles\GTI_Left\image0672.png
# vehicles\GTI_Left\image0673.png
# vehicles\GTI_Left\image0674.png
# vehicles\GTI_Left\image0675.png
# vehicles\GTI_Left\image0676.png
# vehicles\GTI_Left\image0677.png
# vehicles\GTI_Left\image0678.png
# vehicles\GTI_Left\image0679.png
# vehicles\GTI_Left\image0680.png
# vehicles\GTI_Left\image0681.png
# vehicles\GTI_Left\image0682.png
# vehicles\GTI_Left\image0683.png
# vehicles\GTI_Left\image0684.png
# vehicles\GTI_Left\image0685.png
# vehicles\GTI_Left\image0686.png
# vehicles\GTI_Left\image0687.png
# vehicles\GTI_Left\image0688.png
# vehicles\GTI_Left\image0689.png
# vehicles\GTI_Left\image0690.png
# vehicles\GTI_Left\image0691.png
# vehicles\GTI_Left\image0692.png
# vehicles\GTI_Left\image0693.png
# vehicles\GTI_Left\image0694.png
# vehicles\GTI_Left\image0695.png
# vehicles\GTI_Left\image0696.png
# vehicles\GTI_Left\image0697.png
# vehicles\GTI_Left\image0698.png
# vehicles\GTI_Left\image0699.png
# vehicles\GTI_Left\image0700.png
# vehicles\GTI_Left\image0701.png
# vehicles\GTI_Left\image0702.png
# vehicles\GTI_Left\image0703.png
# vehicles\GTI_Left\image0704.png
# vehicles\GTI_Left\image0705.png
# vehicles\GTI_Left\image0706.png
# vehicles\GTI_Left\image0707.png
# vehicles\GTI_Left\image0708.png
# vehicles\GTI_Left\image0709.png
# vehicles\GTI_Left\image0710.png
# vehicles\GTI_Left\image0711.png
# vehicles\GTI_Left\image0712.png
# vehicles\GTI_Left\image0713.png
# vehicles\GTI_Left\image0714.png
# vehicles\GTI_Left\image0715.png
# vehicles\GTI_Left\image0716.png
# vehicles\GTI_Left\image0717.png
# vehicles\GTI_Left\image0718.png
# vehicles\GTI_Left\image0719.png
# vehicles\GTI_Left\image0720.png
# vehicles\GTI_Left\image0721.png
# vehicles\GTI_Left\image0722.png
# vehicles\GTI_Left\image0723.png
# vehicles\GTI_Left\image0724.png
# vehicles\GTI_Left\image0725.png
# vehicles\GTI_Left\image0726.png
# vehicles\GTI_Left\image0727.png
# vehicles\GTI_Left\image0728.png
# vehicles\GTI_Left\image0729.png
# vehicles\GTI_Left\image0730.png
# vehicles\GTI_Left\image0731.png
# vehicles\GTI_Left\image0732.png
# vehicles\GTI_Left\image0733.png
# vehicles\GTI_Left\image0734.png
# vehicles\GTI_Left\image0735.png
# vehicles\GTI_Left\image0736.png
# vehicles\GTI_Left\image0737.png
# vehicles\GTI_Left\image0738.png
# vehicles\GTI_Left\image0739.png
# vehicles\GTI_Left\image0740.png
# vehicles\GTI_Left\image0741.png
# ...
# non-vehicles\GTI\image518.png
# non-vehicles\GTI\image519.png
# non-vehicles\GTI\image52.png
# non-vehicles\GTI\image520.png
# non-vehicles\GTI\image521.png
# non-vehicles\GTI\image522.png
# non-vehicles\GTI\image523.png
# non-vehicles\GTI\image524.png
# non-vehicles\GTI\image525.png
# non-vehicles\GTI\image526.png
# non-vehicles\GTI\image527.png
# non-vehicles\GTI\image528.png
# non-vehicles\GTI\image529.png
# non-vehicles\GTI\image53.png
# non-vehicles\GTI\image530.png
# non-vehicles\GTI\image531.png
# non-vehicles\GTI\image532.png
# non-vehicles\GTI\image533.png
# non-vehicles\GTI\image534.png
# non-vehicles\GTI\image535.png
# non-vehicles\GTI\image536.png
# non-vehicles\GTI\image537.png
# non-vehicles\GTI\image538.png
# non-vehicles\GTI\image539.png
# non-vehicles\GTI\image54.png
# non-vehicles\GTI\image540.png
# non-vehicles\GTI\image541.png
# non-vehicles\GTI\image542.png
# non-vehicles\GTI\image543.png
# non-vehicles\GTI\image544.png
# non-vehicles\GTI\image545.png
# non-vehicles\GTI\image546.png
# non-vehicles\GTI\image547.png
# non-vehicles\GTI\image548.png
# non-vehicles\GTI\image549.png
# non-vehicles\GTI\image55.png
# non-vehicles\GTI\image550.png
# non-vehicles\GTI\image551.png
# non-vehicles\GTI\image552.png
# non-vehicles\GTI\image553.png
# non-vehicles\GTI\image554.png
# non-vehicles\GTI\image555.png
# non-vehicles\GTI\image556.png
# non-vehicles\GTI\image557.png
# non-vehicles\GTI\image558.png
# non-vehicles\GTI\image559.png
# non-vehicles\GTI\image56.png
# non-vehicles\GTI\image560.png
# non-vehicles\GTI\image561.png
# non-vehicles\GTI\image562.png
# non-vehicles\GTI\image563.png
# non-vehicles\GTI\image564.png
# non-vehicles\GTI\image565.png
# non-vehicles\GTI\image566.png
# non-vehicles\GTI\image567.png
# non-vehicles\GTI\image568.png
# non-vehicles\GTI\image569.png
# non-vehicles\GTI\image57.png
# non-vehicles\GTI\image570.png
# non-vehicles\GTI\image571.png
# non-vehicles\GTI\image572.png
# non-vehicles\GTI\image573.png
# non-vehicles\GTI\image574.png
# non-vehicles\GTI\image575.png
# non-vehicles\GTI\image576.png
# non-vehicles\GTI\image577.png
# non-vehicles\GTI\image578.png
# non-vehicles\GTI\image579.png
# non-vehicles\GTI\image58.png
# non-vehicles\GTI\image580.png
# non-vehicles\GTI\image581.png
# non-vehicles\GTI\image582.png
# non-vehicles\GTI\image583.png
# non-vehicles\GTI\image584.png
# non-vehicles\GTI\image585.png
# non-vehicles\GTI\image586.png
# non-vehicles\GTI\image587.png
# non-vehicles\GTI\image588.png
# non-vehicles\GTI\image589.png
# non-vehicles\GTI\image59.png
# non-vehicles\GTI\image590.png
# non-vehicles\GTI\image591.png
# non-vehicles\GTI\image592.png
# non-vehicles\GTI\image593.png
# non-vehicles\GTI\image594.png
# non-vehicles\GTI\image595.png
# non-vehicles\GTI\image596.png
# non-vehicles\GTI\image597.png
# non-vehicles\GTI\image598.png
# non-vehicles\GTI\image599.png
# non-vehicles\GTI\image6.png
# non-vehicles\GTI\image60.png
# non-vehicles\GTI\image600.png
# non-vehicles\GTI\image601.png
# non-vehicles\GTI\image602.png
# non-vehicles\GTI\image603.png
# non-vehicles\GTI\image604.png
# non-vehicles\GTI\image605.png
# non-vehicles\GTI\image606.png
# non-vehicles\GTI\image607.png
# non-vehicles\GTI\image608.png
# non-vehicles\GTI\image609.png
# non-vehicles\GTI\image61.png
# non-vehicles\GTI\image610.png
# non-vehicles\GTI\image611.png
# non-vehicles\GTI\image612.png
# non-vehicles\GTI\image613.png
# non-vehicles\GTI\image614.png
# non-vehicles\GTI\image615.png
# non-vehicles\GTI\image616.png
# non-vehicles\GTI\image617.png
# non-vehicles\GTI\image618.png
# non-vehicles\GTI\image619.png
# non-vehicles\GTI\image62.png
# non-vehicles\GTI\image620.png
# non-vehicles\GTI\image621.png
# non-vehicles\GTI\image622.png
# non-vehicles\GTI\image623.png
# non-vehicles\GTI\image624.png
# non-vehicles\GTI\image625.png
# non-vehicles\GTI\image626.png
# non-vehicles\GTI\image627.png
# non-vehicles\GTI\image628.png
# non-vehicles\GTI\image629.png
# non-vehicles\GTI\image63.png
# non-vehicles\GTI\image630.png
# non-vehicles\GTI\image631.png
# non-vehicles\GTI\image632.png
# non-vehicles\GTI\image633.png
# non-vehicles\GTI\image634.png
# non-vehicles\GTI\image635.png
# non-vehicles\GTI\image636.png
# non-vehicles\GTI\image637.png
# non-vehicles\GTI\image638.png
# non-vehicles\GTI\image639.png
# non-vehicles\GTI\image64.png
# non-vehicles\GTI\image640.png
# non-vehicles\GTI\image641.png
# non-vehicles\GTI\image642.png
# non-vehicles\GTI\image643.png
# non-vehicles\GTI\image644.png
# non-vehicles\GTI\image645.png
# non-vehicles\GTI\image646.png
# non-vehicles\GTI\image647.png
# non-vehicles\GTI\image648.png
# non-vehicles\GTI\image649.png
# non-vehicles\GTI\image65.png
# non-vehicles\GTI\image650.png
# non-vehicles\GTI\image651.png
# non-vehicles\GTI\image652.png
# non-vehicles\GTI\image653.png
# non-vehicles\GTI\image654.png
# non-vehicles\GTI\image655.png
# non-vehicles\GTI\image656.png
# non-vehicles\GTI\image657.png
# non-vehicles\GTI\image658.png
# non-vehicles\GTI\image659.png
# non-vehicles\GTI\image66.png
# non-vehicles\GTI\image660.png
# non-vehicles\GTI\image661.png
# non-vehicles\GTI\image662.png
# non-vehicles\GTI\image663.png
# non-vehicles\GTI\image664.png
# non-vehicles\GTI\image665.png
# non-vehicles\GTI\image666.png
# non-vehicles\GTI\image667.png
# non-vehicles\GTI\image668.png
# non-vehicles\GTI\image669.png
# non-vehicles\GTI\image67.png
# non-vehicles\GTI\image670.png
# non-vehicles\GTI\image671.png
# non-vehicles\GTI\image672.png
# non-vehicles\GTI\image673.png
# non-vehicles\GTI\image674.png
# non-vehicles\GTI\image675.png
# non-vehicles\GTI\image676.png
# non-vehicles\GTI\image677.png
# non-vehicles\GTI\image678.png
# non-vehicles\GTI\image679.png
# non-vehicles\GTI\image68.png
# non-vehicles\GTI\image680.png
# non-vehicles\GTI\image681.png
# non-vehicles\GTI\image682.png
# non-vehicles\GTI\image683.png
# non-vehicles\GTI\image684.png
# non-vehicles\GTI\image685.png
# non-vehicles\GTI\image686.png
# non-vehicles\GTI\image687.png
# non-vehicles\GTI\image688.png
# non-vehicles\GTI\image689.png
# non-vehicles\GTI\image69.png
# non-vehicles\GTI\image690.png
# non-vehicles\GTI\image691.png
# non-vehicles\GTI\image692.png
# non-vehicles\GTI\image693.png
# non-vehicles\GTI\image694.png
# non-vehicles\GTI\image695.png
# non-vehicles\GTI\image696.png
# non-vehicles\GTI\image697.png
# non-vehicles\GTI\image698.png
# non-vehicles\GTI\image699.png
# non-vehicles\GTI\image7.png
# non-vehicles\GTI\image70.png
# non-vehicles\GTI\image700.png
# non-vehicles\GTI\image701.png
# non-vehicles\GTI\image702.png
# non-vehicles\GTI\image703.png
# non-vehicles\GTI\image704.png
# non-vehicles\GTI\image705.png
# non-vehicles\GTI\image706.png
# non-vehicles\GTI\image707.png
# non-vehicles\GTI\image708.png
# non-vehicles\GTI\image709.png
# non-vehicles\GTI\image71.png
# non-vehicles\GTI\image710.png
# non-vehicles\GTI\image711.png
# non-vehicles\GTI\image712.png
# non-vehicles\GTI\image713.png
# non-vehicles\GTI\image714.png
# non-vehicles\GTI\image715.png
# non-vehicles\GTI\image716.png
# non-vehicles\GTI\image717.png
# non-vehicles\GTI\image718.png
# non-vehicles\GTI\image719.png
# non-vehicles\GTI\image72.png
# non-vehicles\GTI\image720.png
# non-vehicles\GTI\image721.png
# non-vehicles\GTI\image722.png
# non-vehicles\GTI\image723.png
# non-vehicles\GTI\image724.png
# non-vehicles\GTI\image725.png
# non-vehicles\GTI\image726.png
# non-vehicles\GTI\image727.png
# non-vehicles\GTI\image728.png
# non-vehicles\GTI\image729.png
# non-vehicles\GTI\image73.png
# non-vehicles\GTI\image730.png
# non-vehicles\GTI\image731.png
# non-vehicles\GTI\image732.png
# non-vehicles\GTI\image733.png
# non-vehicles\GTI\image734.png
# non-vehicles\GTI\image735.png
# non-vehicles\GTI\image736.png
# non-vehicles\GTI\image737.png
# non-vehicles\GTI\image738.png
# non-vehicles\GTI\image739.png
# non-vehicles\GTI\image74.png
# non-vehicles\GTI\image740.png
# non-vehicles\GTI\image741.png
# non-vehicles\GTI\image742.png
# non-vehicles\GTI\image743.png
# non-vehicles\GTI\image744.png
# non-vehicles\GTI\image745.png
# non-vehicles\GTI\image746.png
# non-vehicles\GTI\image747.png
# non-vehicles\GTI\image748.png
# non-vehicles\GTI\image749.png
# non-vehicles\GTI\image75.png
# non-vehicles\GTI\image750.png
# non-vehicles\GTI\image751.png
# non-vehicles\GTI\image752.png
# non-vehicles\GTI\image753.png
# non-vehicles\GTI\image754.png
# non-vehicles\GTI\image755.png
# non-vehicles\GTI\image756.png
# non-vehicles\GTI\image757.png
# non-vehicles\GTI\image758.png
# non-vehicles\GTI\image759.png
# non-vehicles\GTI\image76.png
# non-vehicles\GTI\image760.png
# non-vehicles\GTI\image761.png
# non-vehicles\GTI\image762.png
# non-vehicles\GTI\image763.png
# non-vehicles\GTI\image764.png
# non-vehicles\GTI\image765.png
# non-vehicles\GTI\image766.png
# non-vehicles\GTI\image767.png
# non-vehicles\GTI\image768.png
# non-vehicles\GTI\image769.png
# non-vehicles\GTI\image77.png
# non-vehicles\GTI\image770.png
# non-vehicles\GTI\image771.png
# non-vehicles\GTI\image772.png
# non-vehicles\GTI\image773.png
# non-vehicles\GTI\image774.png
# non-vehicles\GTI\image775.png
# non-vehicles\GTI\image776.png
# non-vehicles\GTI\image777.png
# non-vehicles\GTI\image778.png
# non-vehicles\GTI\image779.png
# non-vehicles\GTI\image78.png
# non-vehicles\GTI\image780.png
# non-vehicles\GTI\image781.png
# non-vehicles\GTI\image782.png
# non-vehicles\GTI\image783.png
# non-vehicles\GTI\image784.png
# non-vehicles\GTI\image785.png
# non-vehicles\GTI\image786.png
# non-vehicles\GTI\image787.png
# non-vehicles\GTI\image788.png
# non-vehicles\GTI\image789.png
# non-vehicles\GTI\image79.png
# non-vehicles\GTI\image790.png
# non-vehicles\GTI\image791.png
# non-vehicles\GTI\image792.png
# non-vehicles\GTI\image793.png
# non-vehicles\GTI\image794.png
# non-vehicles\GTI\image795.png
# non-vehicles\GTI\image796.png
# non-vehicles\GTI\image797.png
# non-vehicles\GTI\image798.png
# non-vehicles\GTI\image799.png
# non-vehicles\GTI\image8.png
# non-vehicles\GTI\image80.png
# non-vehicles\GTI\image800.png
# non-vehicles\GTI\image801.png
# non-vehicles\GTI\image802.png
# non-vehicles\GTI\image803.png
# non-vehicles\GTI\image804.png
# non-vehicles\GTI\image805.png
# non-vehicles\GTI\image806.png
# non-vehicles\GTI\image807.png
# non-vehicles\GTI\image808.png
# non-vehicles\GTI\image809.png
# non-vehicles\GTI\image81.png
# non-vehicles\GTI\image810.png
# non-vehicles\GTI\image811.png
# non-vehicles\GTI\image812.png
# non-vehicles\GTI\image813.png
# non-vehicles\GTI\image814.png
# non-vehicles\GTI\image815.png
# non-vehicles\GTI\image816.png
# non-vehicles\GTI\image817.png
# non-vehicles\GTI\image818.png
# non-vehicles\GTI\image819.png
# non-vehicles\GTI\image82.png
# non-vehicles\GTI\image820.png
# non-vehicles\GTI\image821.png
# non-vehicles\GTI\image822.png
# non-vehicles\GTI\image823.png
# non-vehicles\GTI\image824.png
# non-vehicles\GTI\image825.png
# non-vehicles\GTI\image826.png
# non-vehicles\GTI\image827.png
# non-vehicles\GTI\image828.png
# non-vehicles\GTI\image829.png
# non-vehicles\GTI\image83.png
# non-vehicles\GTI\image830.png
# non-vehicles\GTI\image831.png
# non-vehicles\GTI\image832.png
# non-vehicles\GTI\image833.png
# non-vehicles\GTI\image834.png
# non-vehicles\GTI\image835.png
# non-vehicles\GTI\image836.png
# non-vehicles\GTI\image837.png
# non-vehicles\GTI\image838.png
# non-vehicles\GTI\image839.png
# non-vehicles\GTI\image84.png
# non-vehicles\GTI\image840.png
# non-vehicles\GTI\image841.png
# non-vehicles\GTI\image842.png
# non-vehicles\GTI\image843.png
# non-vehicles\GTI\image844.png
# non-vehicles\GTI\image845.png
# non-vehicles\GTI\image846.png
# non-vehicles\GTI\image847.png
# non-vehicles\GTI\image848.png
# non-vehicles\GTI\image849.png
# non-vehicles\GTI\image85.png
# non-vehicles\GTI\image850.png
# non-vehicles\GTI\image851.png
# non-vehicles\GTI\image852.png
# non-vehicles\GTI\image853.png
# non-vehicles\GTI\image854.png
# non-vehicles\GTI\image855.png
# non-vehicles\GTI\image856.png
# non-vehicles\GTI\image857.png
# non-vehicles\GTI\image858.png
# non-vehicles\GTI\image859.png
# non-vehicles\GTI\image86.png
# non-vehicles\GTI\image860.png
# non-vehicles\GTI\image861.png
# non-vehicles\GTI\image862.png
# non-vehicles\GTI\image863.png
# non-vehicles\GTI\image864.png
# non-vehicles\GTI\image865.png
# non-vehicles\GTI\image866.png
# non-vehicles\GTI\image867.png
# non-vehicles\GTI\image868.png
# non-vehicles\GTI\image869.png
# non-vehicles\GTI\image87.png
# non-vehicles\GTI\image870.png
# non-vehicles\GTI\image871.png
# non-vehicles\GTI\image872.png
# non-vehicles\GTI\image873.png
# non-vehicles\GTI\image874.png
# non-vehicles\GTI\image875.png
# non-vehicles\GTI\image876.png
# non-vehicles\GTI\image877.png
# non-vehicles\GTI\image878.png
# non-vehicles\GTI\image879.png
# non-vehicles\GTI\image88.png
# non-vehicles\GTI\image880.png
# non-vehicles\GTI\image881.png
# non-vehicles\GTI\image882.png
# non-vehicles\GTI\image883.png
# non-vehicles\GTI\image884.png
# non-vehicles\GTI\image885.png
# non-vehicles\GTI\image886.png
# non-vehicles\GTI\image887.png
# non-vehicles\GTI\image888.png
# non-vehicles\GTI\image889.png
# non-vehicles\GTI\image89.png
# non-vehicles\GTI\image890.png
# non-vehicles\GTI\image891.png
# non-vehicles\GTI\image892.png
# non-vehicles\GTI\image893.png
# non-vehicles\GTI\image894.png
# non-vehicles\GTI\image895.png
# non-vehicles\GTI\image896.png
# non-vehicles\GTI\image897.png
# non-vehicles\GTI\image898.png
# non-vehicles\GTI\image899.png
# non-vehicles\GTI\image9.png
# non-vehicles\GTI\image90.png
# non-vehicles\GTI\image900.png
# non-vehicles\GTI\image901.png
# non-vehicles\GTI\image902.png
# non-vehicles\GTI\image903.png
# non-vehicles\GTI\image904.png
# non-vehicles\GTI\image905.png
# non-vehicles\GTI\image906.png
# non-vehicles\GTI\image907.png
# non-vehicles\GTI\image908.png
# non-vehicles\GTI\image909.png
# non-vehicles\GTI\image91.png
# non-vehicles\GTI\image910.png
# non-vehicles\GTI\image911.png
# non-vehicles\GTI\image912.png
# non-vehicles\GTI\image913.png
# non-vehicles\GTI\image914.png
# non-vehicles\GTI\image915.png
# non-vehicles\GTI\image916.png
# non-vehicles\GTI\image917.png
# non-vehicles\GTI\image918.png
# non-vehicles\GTI\image919.png
# non-vehicles\GTI\image92.png
# non-vehicles\GTI\image920.png
# non-vehicles\GTI\image921.png
# non-vehicles\GTI\image922.png
# non-vehicles\GTI\image923.png
# non-vehicles\GTI\image924.png
# non-vehicles\GTI\image925.png
# non-vehicles\GTI\image926.png
# non-vehicles\GTI\image927.png
# non-vehicles\GTI\image928.png
# non-vehicles\GTI\image929.png
# non-vehicles\GTI\image93.png
# non-vehicles\GTI\image930.png
# non-vehicles\GTI\image931.png
# non-vehicles\GTI\image932.png
# non-vehicles\GTI\image933.png
# non-vehicles\GTI\image934.png
# non-vehicles\GTI\image935.png
# non-vehicles\GTI\image936.png
# non-vehicles\GTI\image937.png
# non-vehicles\GTI\image938.png
# non-vehicles\GTI\image939.png
# non-vehicles\GTI\image94.png
# non-vehicles\GTI\image940.png
# non-vehicles\GTI\image941.png
# non-vehicles\GTI\image942.png
# non-vehicles\GTI\image943.png
# non-vehicles\GTI\image944.png
# non-vehicles\GTI\image945.png
# non-vehicles\GTI\image946.png
# non-vehicles\GTI\image947.png
# non-vehicles\GTI\image948.png
# non-vehicles\GTI\image949.png
# non-vehicles\GTI\image95.png
# non-vehicles\GTI\image950.png
# non-vehicles\GTI\image951.png
# non-vehicles\GTI\image952.png
# non-vehicles\GTI\image953.png
# non-vehicles\GTI\image954.png
# non-vehicles\GTI\image955.png
# non-vehicles\GTI\image956.png
# non-vehicles\GTI\image957.png
# non-vehicles\GTI\image958.png
# non-vehicles\GTI\image959.png
# non-vehicles\GTI\image96.png
# non-vehicles\GTI\image960.png
# non-vehicles\GTI\image961.png
# non-vehicles\GTI\image962.png
# non-vehicles\GTI\image963.png
# non-vehicles\GTI\image964.png
# non-vehicles\GTI\image965.png
# non-vehicles\GTI\image966.png
# non-vehicles\GTI\image967.png
# non-vehicles\GTI\image968.png
# non-vehicles\GTI\image969.png
# non-vehicles\GTI\image97.png
# non-vehicles\GTI\image970.png
# non-vehicles\GTI\image971.png
# non-vehicles\GTI\image972.png
# non-vehicles\GTI\image973.png
# non-vehicles\GTI\image974.png
# non-vehicles\GTI\image975.png
# non-vehicles\GTI\image976.png
# non-vehicles\GTI\image977.png
# non-vehicles\GTI\image978.png
# non-vehicles\GTI\image979.png
# non-vehicles\GTI\image98.png
# non-vehicles\GTI\image980.png
# non-vehicles\GTI\image981.png
# non-vehicles\GTI\image982.png
# non-vehicles\GTI\image983.png
# non-vehicles\GTI\image984.png
# non-vehicles\GTI\image985.png
# non-vehicles\GTI\image986.png
# non-vehicles\GTI\image987.png
# non-vehicles\GTI\image988.png
# non-vehicles\GTI\image989.png
# non-vehicles\GTI\image99.png
# non-vehicles\GTI\image990.png
# non-vehicles\GTI\image991.png
# non-vehicles\GTI\image992.png
# non-vehicles\GTI\image993.png
# non-vehicles\GTI\image994.png
# non-vehicles\GTI\image995.png
# non-vehicles\GTI\image996.png
# non-vehicles\GTI\image997.png
# non-vehicles\GTI\image998.png
# non-vehicles\GTI\image999.png
# (17760, 4932)

# %%
X_scaler = StandardScaler().fit(X_training)
print (X_training.shape)
# Apply the scaler to X
scaled_X = X_scaler.transform(X_training)

y_label = np.hstack((np.ones(len(training_vehicles_features)), 
              np.zeros(len(training_non_vehicles_features))))
print (scaled_X.shape, y_label.shape)
rand_state = np.random.randint(0, 100)
X_train, X_test, y_train, y_test = train_test_split(
    scaled_X, y_label, test_size=0.2, random_state=rand_state)
# Out:
# (17760, 4932)
# (17760, 4932) (17760,)

# %%
# linear SVC 
svc = LinearSVC()
svc.fit(X_train, y_train)

# Check the score of the SVC
print('Accuracy of SVC = ', round(svc.score(X_test, y_test), 2))

n_predict = 10
print('SVC predicts: ', svc.predict(X_test[0:n_predict]))
print('For these',n_predict, 'labels: ', y_test[0:n_predict])
# Out:
# Accuracy of SVC =  0.97
# SVC predicts:  [ 1.  0.  1.  0.  1.  1.  0.  0.  1.  0.]
# For these 10 labels:  [ 1.  0.  1.  0.  1.  1.  0.  0.  1.  0.]

# %%
# Define a function to extract features from a single image window
# This function is very similar to extract_features()
# just for a single image rather than list of images
def single_img_features(img, color_space='RGB', spatial_size=(32, 32),
                        hist_bins=32, orient=9, 
                        pix_per_cell=8, cell_per_block=2, hog_channel=0,
                        spatial_feat=True, hist_feat=True, hog_feat=True):    
    #1) Define an empty list to receive features
    img_features = []
    #2) Apply color conversion if other than 'RGB'
    if color_space != 'RGB':
        if color_space == 'HSV':
            feature_image = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
        elif color_space == 'LUV':
            feature_image = cv2.cvtColor(img, cv2.COLOR_RGB2LUV)
        elif color_space == 'HLS':
            feature_image = cv2.cvtColor(img, cv2.COLOR_RGB2HLS)
        elif color_space == 'YUV':
            feature_image = cv2.cvtColor(img, cv2.COLOR_RGB2YUV)
        elif color_space == 'YCrCb':
            feature_image = cv2.cvtColor(img, cv2.COLOR_RGB2YCrCb)
    else: feature_image = np.copy(img)      
    #3) Compute spatial features if flag is set
    if spatial_feat == True:
        spatial_features = bin_spatial(feature_image, size=spatial_size)
        #4) Append features to list
        img_features.append(spatial_features)
    #5) Compute histogram features if flag is set
    if hist_feat == True:
        hist_features = color_hist(feature_image, nbins=hist_bins)
        #6) Append features to list
        img_features.append(hist_features)
    #7) Compute HOG features if flag is set
    if hog_feat == True:
        if hog_channel == 'ALL':
            hog_features = []
            for channel in range(feature_image.shape[2]):
                hog_features.extend(get_hog_features(feature_image[:,:,channel], 
                                    orient, pix_per_cell, cell_per_block, 
                                    vis=False, feature_vec=True))      
        else:
            hog_features = get_hog_features(feature_image[:,:,hog_channel], orient, 
                        pix_per_cell, cell_per_block, vis=False, feature_vec=True)
        #8) Append features to list
        img_features.append(hog_features)

    #9) Return concatenated array of features
    return np.concatenate(img_features)

# Define a function that takes an image,
# start and stop positions in both x and y, 
# window size (x and y dimensions),  
# and overlap fraction (for both x and y)
def slide_window(img, x_start_stop=[None, None], y_start_stop=[None, None], 
                    xy_window=(64, 64), xy_overlap=(0.5, 0.5)):
    # If x and/or y start/stop positions not defined, set to image size
    if x_start_stop[0] == None:
        x_start_stop[0] = 0
    if x_start_stop[1] == None:
        x_start_stop[1] = img.shape[1]
    if y_start_stop[0] == None:
        y_start_stop[0] = 0
    if y_start_stop[1] == None:
        y_start_stop[1] = img.shape[0]
    # Compute the span of the region to be searched    
    xspan = x_start_stop[1] - x_start_stop[0]
    yspan = y_start_stop[1] - y_start_stop[0]
    # Compute the number of pixels per step in x/y
    nx_pix_per_step = np.int(xy_window[0]*(1 - xy_overlap[0]))
    ny_pix_per_step = np.int(xy_window[1]*(1 - xy_overlap[1]))
    # Compute the number of windows in x/y
    nx_buffer = np.int(xy_window[0]*(xy_overlap[0]))
    ny_buffer = np.int(xy_window[1]*(xy_overlap[1]))
    nx_windows = np.int((xspan-nx_buffer)/nx_pix_per_step) 
    ny_windows = np.int((yspan-ny_buffer)/ny_pix_per_step) 
    # Initialize a list to append window positions to
    window_list = []
    # Loop through finding x and y window positions
    # Note: you could vectorize this step, but in practice
    # you'll be considering windows one by one with your
    # classifier, so looping makes sense
    for ys in range(ny_windows):
        for xs in range(nx_windows):
            # Calculate window position
            startx = xs*nx_pix_per_step + x_start_stop[0]
            endx = startx + xy_window[0]
            starty = ys*ny_pix_per_step + y_start_stop[0]
            endy = starty + xy_window[1]
            
            # Append window position to list
            window_list.append(((startx, starty), (endx, endy)))
    # Return the list of windows
    return window_list

# Define a function to draw bounding boxes
def draw_boxes(img, bboxes, color=(0, 0, 255), thick=6):
    # Make a copy of the image
    imcopy = np.copy(img)
    # Iterate through the bounding boxes
    for bbox in bboxes:
        # Draw a rectangle given bbox coordinates
        cv2.rectangle(imcopy, bbox[0], bbox[1], color, thick)
    # Return the image copy with boxes drawn
    return imcopy


# Define a function you will pass an image 
# and the list of windows to be searched (output of slide_windows())
def search_windows(img, windows, clf, scaler, color_space='RGB', 
                    spatial_size=(32, 32), hist_bins=32, 
                    hist_range=(0, 256), orient=9, 
                    pix_per_cell=8, cell_per_block=2, 
                    hog_channel=0, spatial_feat=True, 
                    hist_feat=True, hog_feat=True):

    #1) Create an empty list to receive positive detection windows
    on_windows = []
    #2) Iterate over all windows in the list
    for window in windows:
        #3) Extract the test window from original image
        test_img = cv2.resize(img[window[0][1]:window[1][1], window[0][0]:window[1][0]], (64, 64))      
        #4) Extract features for that window using single_img_features()
        features = single_img_features(test_img, color_space=color_space, 
                            spatial_size=spatial_size, hist_bins=hist_bins, 
                            orient=orient, pix_per_cell=pix_per_cell, 
                            cell_per_block=cell_per_block, 
                            hog_channel=hog_channel, spatial_feat=spatial_feat, 
                            hist_feat=hist_feat, hog_feat=hog_feat)

        #5) Scale extracted features to be fed to classifier
        print (features.shape)
        test_features = scaler.transform(np.array(features).reshape(-1, 1))
        #6) Predict using your classifier
        prediction = clf.predict(test_features)
        #7) If positive (prediction == 1) then save the window
        if prediction == 1:
            on_windows.append(window)
    #8) Return windows for positive detections
    return on_windows

# %%
# Define a single function that can extract features using hog sub-sampling and make predictions
def find_cars(img, ystart, ystop, scale, cspace, hog_channel, svc, X_scaler, orient, 
              pix_per_cell, cell_per_block, spatial_size, hist_bins, show_all_rectangles=False):
    
    # array of rectangles where cars were detected
    rectangles = []
    
    img = img.astype(np.float32)/255
    
    img_tosearch = img[ystart:ystop,:,:]

    # apply color conversion if other than 'RGB'
    if cspace != 'RGB':
        if cspace == 'HSV':
            ctrans_tosearch = cv2.cvtColor(img_tosearch, cv2.COLOR_RGB2HSV)
        elif cspace == 'LUV':
            ctrans_tosearch = cv2.cvtColor(img_tosearch, cv2.COLOR_RGB2LUV)
        elif cspace == 'HLS':
            ctrans_tosearch = cv2.cvtColor(img_tosearch, cv2.COLOR_RGB2HLS)
        elif cspace == 'YUV':
            ctrans_tosearch = cv2.cvtColor(img_tosearch, cv2.COLOR_RGB2YUV)
        elif cspace == 'YCrCb':
            ctrans_tosearch = cv2.cvtColor(img_tosearch, cv2.COLOR_RGB2YCrCb)
    else: ctrans_tosearch = np.copy(image)   
    
    # rescale image if other than 1.0 scale
    if scale != 1:
        imshape = ctrans_tosearch.shape
        ctrans_tosearch = cv2.resize(ctrans_tosearch, (np.int(imshape[1]/scale), np.int(imshape[0]/scale)))
    
    # select colorspace channel for HOG 
    if hog_channel == 'ALL':
        ch1 = ctrans_tosearch[:,:,0]
        ch2 = ctrans_tosearch[:,:,1]
        ch3 = ctrans_tosearch[:,:,2]
    else: 
        ch1 = ctrans_tosearch[:,:,hog_channel]

    # Define blocks and steps as above
    nxblocks = (ch1.shape[1] // pix_per_cell)+1  #-1
    nyblocks = (ch1.shape[0] // pix_per_cell)+1  #-1 
    nfeat_per_block = orient*cell_per_block**2
    # 64 was the orginal sampling rate, with 8 cells and 8 pix per cell
    window = 64
    nblocks_per_window = (window // pix_per_cell)-1 
    cells_per_step = 2  # Instead of overlap, define how many cells to step
    nxsteps = (nxblocks - nblocks_per_window) // cells_per_step
    nysteps = (nyblocks - nblocks_per_window) // cells_per_step
    
    # Compute individual channel HOG features for the entire image
    hog1 = get_hog_features(ch1, orient, pix_per_cell, cell_per_block, feature_vec=False)   
    if hog_channel == 'ALL':
        hog2 = get_hog_features(ch2, orient, pix_per_cell, cell_per_block, feature_vec=False)
        hog3 = get_hog_features(ch3, orient, pix_per_cell, cell_per_block, feature_vec=False)
    
    for xb in range(nxsteps):
        for yb in range(nysteps):
            ypos = yb*cells_per_step
            xpos = xb*cells_per_step
            # Extract HOG for this patch
            hog_feat1 = hog1[ypos:ypos+nblocks_per_window, xpos:xpos+nblocks_per_window].ravel()
            if hog_channel == 'ALL':
                hog_feat2 = hog2[ypos:ypos+nblocks_per_window, xpos:xpos+nblocks_per_window].ravel() 
                hog_feat3 = hog3[ypos:ypos+nblocks_per_window, xpos:xpos+nblocks_per_window].ravel() 
                hog_features = np.hstack((hog_feat1, hog_feat2, hog_feat3))
            else:
                hog_features = hog_feat1

            xleft = xpos*pix_per_cell
            ytop = ypos*pix_per_cell
            print(hog_features.shape)
            test_prediction = svc.predict(np.array(hog_features).reshape(-1, 1))
            
            if test_prediction == 1 or show_all_rectangles:
                xbox_left = np.int(xleft*scale)
                ytop_draw = np.int(ytop*scale)
                win_draw = np.int(window*scale)
                rectangles.append(((xbox_left, ytop_draw+ystart),(xbox_left+win_draw,ytop_draw+win_draw+ystart)))
                
    return rectangles

# %%
image = mpimg.imread('./test_images/test1.jpg')
### TODO: Tweak these parameters and see how the results change.
color_space = 'RGB' # Can be RGB, HSV, LUV, HLS, YUV, YCrCb
orient = 9  # HOG orientations
pix_per_cell = 8 # HOG pixels per cell
cell_per_block = 2 # HOG cells per block
hog_channel = 0 # Can be 0, 1, 2, or "ALL"
spatial_size = (16, 16) # Spatial binning dimensions
hist_bins = 16    # Number of histogram bins
spatial_feat = True # Spatial features on or off
hist_feat = True # Histogram features on or off
hog_feat = True # HOG features on or off
y_start_stop = [None, None] # Min and max in y to search in slide_window()

windows = slide_window(image, x_start_stop=[None, None], y_start_stop=y_start_stop, 
                    xy_window=(96, 96), xy_overlap=(0.5, 0.5))

hot_windows = search_windows(image, windows, svc, X_scaler, color_space=color_space, 
                        spatial_size=spatial_size, hist_bins=hist_bins, 
                        orient=orient, pix_per_cell=pix_per_cell, 
                        cell_per_block=cell_per_block, 
                        hog_channel=hog_channel, spatial_feat=spatial_feat, 
                        hist_feat=hist_feat, hog_feat=hog_feat)                       

window_img = draw_boxes(draw_image, hot_windows, color=(0, 0, 255), thick=6)                    

plt.imshow(window_img)
# Out:
# (1188,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-112-dd776175ab76> in <module>()
#      23 hog_channel = 'ALL' # Can be 0, 1, 2, or "ALL"
#      24
# ---> 25 rectangles = find_cars(test_img, ystart, ystop, 1.0, colorspace, hog_channel, svc, None, orient, pix_per_cell, cell_per_block, None, None)
#      26
#      27 print(len(rectangles), 'rectangles found in image')
#
# <ipython-input-111-17bd358fded6> in find_cars(img, ystart, ystop, scale, cspace, hog_channel, svc, X_scaler, orient, pix_per_cell, cell_per_block, spatial_size, hist_bins, show_all_rectangles)
#      70             ytop = ypos*pix_per_cell
#      71             print(hog_features.shape)
# ---> 72             test_prediction = svc.predict(np.array(hog_features).reshape(-1, 1))
#      73
#      74             if test_prediction == 1 or show_all_rectangles:
#
# ~\AppData\Local\conda\conda\envs\carnd-term1\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     322             Predicted class label per sample.
#     323         """
# --> 324         scores = self.decision_function(X)
#     325         if len(scores.shape) == 1:
#     326             indices = (scores > 0).astype(np.int)
#
# ~\AppData\Local\conda\conda\envs\carnd-term1\lib\site-packages\sklearn\linear_model\base.py in decision_function(self, X)
#     303         if X.shape[1] != n_features:
#     304             raise ValueError("X has %d features per sample; expecting %d"
# --> 305                              % (X.shape[1], n_features))
#     306
#     307         scores = safe_sparse_dot(X, self.coef_.T,
#
# ValueError: X has 1 features per sample; expecting 1764
